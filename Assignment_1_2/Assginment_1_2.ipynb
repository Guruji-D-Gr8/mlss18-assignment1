# %% [markdown]
# Welcome to your assignment on Pandas and Matplotlib!
# In case you face any difficulty or you have any doubts related to this assignment, or Pandas or Matplotlib in general, do not hesitate to ask on the Slack channel.

# %% [markdown]
# # Importing Libraries
#
# We shall start by importing the Python libraries you will need to run the code.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline

# %% [markdown]
# # Importing the Data
#
# Import the data stored in "day.csv" using Pandas and store it in a DataFrame named df.
# Also, since the data contains many columns that you may find unnecessary, you may drop them off.

# %%
#Fill in the incomplete code here
df = pd.read_csv("day.csv")

drop_list = ['instant', 'season', 'yr']
#Write code below to drop the columns given in drop_list. You can add or remove columns as per your convinience.
df.drop(drop_list,axis=1,inplace=True)
df.drop(['holiday','weathersit'],axis=1,inplace=False)
# Out:
#          dteday  mnth  weekday  workingday      temp     atemp       hum  \
# 0    2011-01-01     1        6           0  0.344167  0.363625  0.805833
# 1    2011-01-02     1        0           0  0.363478  0.353739  0.696087
# 2    2011-01-03     1        1           1  0.196364  0.189405  0.437273
# 3    2011-01-04     1        2           1  0.200000  0.212122  0.590435
# 4    2011-01-05     1        3           1  0.226957  0.229270  0.436957
# 5    2011-01-06     1        4           1  0.204348  0.233209  0.518261
# 6    2011-01-07     1        5           1  0.196522  0.208839  0.498696
# 7    2011-01-08     1        6           0  0.165000  0.162254  0.535833
# 8    2011-01-09     1        0           0  0.138333  0.116175  0.434167
# 9    2011-01-10     1        1           1  0.150833  0.150888  0.482917
# 10   2011-01-11     1        2           1  0.169091  0.191464  0.686364
# 11   2011-01-12     1        3           1  0.172727  0.160473  0.599545
# 12   2011-01-13     1        4           1  0.165000  0.150883  0.470417
# 13   2011-01-14     1        5           1  0.160870  0.188413  0.537826
# 14   2011-01-15     1        6           0  0.233333  0.248112  0.498750
# 15   2011-01-16     1        0           0  0.231667  0.234217  0.483750
# 16   2011-01-17     1        1           0  0.175833  0.176771  0.537500
# 17   2011-01-18     1        2           1  0.216667  0.232333  0.861667
# 18   2011-01-19     1        3           1  0.292174  0.298422  0.741739
# 19   2011-01-20     1        4           1  0.261667  0.255050  0.538333
# 20   2011-01-21     1        5           1  0.177500  0.157833  0.457083
# 21   2011-01-22     1        6           0  0.059130  0.079070  0.400000
# 22   2011-01-23     1        0           0  0.096522  0.098839  0.436522
# 23   2011-01-24     1        1           1  0.097391  0.117930  0.491739
# 24   2011-01-25     1        2           1  0.223478  0.234526  0.616957
# 25   2011-01-26     1        3           1  0.217500  0.203600  0.862500
# 26   2011-01-27     1        4           1  0.195000  0.219700  0.687500
# 27   2011-01-28     1        5           1  0.203478  0.223317  0.793043
# 28   2011-01-29     1        6           0  0.196522  0.212126  0.651739
# 29   2011-01-30     1        0           0  0.216522  0.250322  0.722174
# ..          ...   ...      ...         ...       ...       ...       ...
# 701  2012-12-02    12        0           0  0.347500  0.359208  0.823333
# 702  2012-12-03    12        1           1  0.452500  0.455796  0.767500
# 703  2012-12-04    12        2           1  0.475833  0.469054  0.733750
# 704  2012-12-05    12        3           1  0.438333  0.428012  0.485000
# 705  2012-12-06    12        4           1  0.255833  0.258204  0.508750
# 706  2012-12-07    12        5           1  0.320833  0.321958  0.764167
# 707  2012-12-08    12        6           0  0.381667  0.389508  0.911250
# 708  2012-12-09    12        0           0  0.384167  0.390146  0.905417
# 724   0.168726     440         573  1013
# 725   0.316546       9         432   441
# 726   0.350133     247        1867  2114
# 727   0.155471     644        2451  3095
# 728   0.124383     159        1182  1341
# 729   0.350754     364        1432  1796
# 730   0.154846     439        2290  2729
#
# [731 rows x 11 columns]

# %% [markdown]
# # Plotting the data
#
# With the data stored in our Pandas dataframe, we are now ready to plot the data to gain some insights on the data.
# We will define functions for each plot to make our code re-usable.

# %% [markdown]
# But before plotting, you must set some parameters common to all the plots. This is done in order to make the visibility and readability of the plots better. This can be done by changing the default rc settings defined in the matplotlibrc configuration files. One example is given.

# %%
#Set plot size to 14" x 7" (Solved Exapmle)
matplotlib.rc('figure', figsize = (14, 7))

#Set the font size to 15
matplotlib.rcParams['font.size'] = 15

#Do not display the top and right frame lines
matplotlib.rc('axes.spines', top = False, right = False)
#You can try experimenting with the background color, grid lines and font style
matplotlib.rcParams['lines.linewidth'] = 2
matplotlib.rcParams['lines.color'] = 'r'
matplotlib.rc('axes', facecolor='white')

# %% [markdown]
# ## Scatter Plot
#
# This is the most used plot for gaing insight into data while dealing with Machine Learning problems. For your convenience, the code for scatter plot is given as an exapmle.

# %%
def scatter_plot(x_data, y_data, x_label, y_label, title):
    
    fig, ax = plt.subplots()
    ax.scatter(x_data, y_data, s = 20, color = '#6d0ff1', alpha = 0.75)
    
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    
scatter_plot(x_data = df['temp']
            , y_data = df['cnt']
            , x_label = 'Normalized temperature (C)'
            , y_label = 'Check outs'
            , title = 'Number of Check Outs vs Temperature')

# %% [markdown]
# # Histogram

# %%
#Fill the function given below
def histogram(data, x_label, y_label, title):
    fig, ax = plt.subplots()
    ax.hist(data,density=True, color = '#03ff5f', alpha = .9)
    
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

#Calling the function "histogram"
histogram(data = df['registered']
           , x_label = 'Check outs'
           , y_label = 'Frequency'
           , title = 'Distribution of Registered Check Outs')

# %% [markdown]
# # Line Plot

# %%
#Fill the function given below
def lineplot(x_data, y_data, x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.plot(x_data, y_data, color = '#ccc000', alpha = 0.75)
     
    
    
#Calling the function to create plot
lineplot(x_data = df['dteday']
         , y_data = df['cnt']
         , x_label = 'Date'
         , y_label = 'Total Checkouts'
         , title = 'Total Checkouts for Each Day')

# %% [markdown]
# # Comparing Two Line Plots
#
# This is useful for comparing two variables over a third variable. It must be noted that these variables may have different scales (they do in the example given below).

# %%
#Fill the function given below
def lineplot2y(x_data, x_label, y1_data, y1_label, y2_data, y2_label, title):
    plt.plot(x_data, y1_data,color='g',label=y1_label)
    plt.plot(x_data, y2_data,color='orange', label=y2_label)
    plt.xlabel(x_label)
    plt.ylabel('Checkouts')
    plt.title(title)
    plt.legend(loc=2)
    plt.show()
    

#Calling the function to create plot
lineplot2y(x_data = df['dteday']
           , x_label = 'Date'
           , y1_data = df['casual']
           , y1_label = 'Casual Checkouts'
           , y2_data = df['registered']
           , y2_label = 'Registered Checkouts'
           , title = 'No. of Registered vs Casual Checkouts for Each Day')



#INDIAN FLAG :D

# %% [markdown]
# # And You're Done!
#
# Congratulations on completing the second part of your first assignment. There are lots of plots you can explore and try on the numerous fields given in "day.csv". You can also do numpy operations on the data to derive more meaningful insights if you wish to.

# %% [markdown]
# You need to submit this Python notebook for this part of the assignment.
